# %%
# Import library

from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
img_new = cv2.imread("/content/file2.jpg")
cv2_imshow(img_new)
img_new_gray = cv2.cvtColor(img_new,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_new_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=895x607>
# <PIL.Image.Image image mode=L size=895x607>

# %%
img_new_2 = cv2.imread("/content/file.jpg")
cv2_imshow(img_new_2)
img_new_2_gray = cv2.cvtColor(img_new_2,cv2.COLOR_BGR2GRAY)
cv2_imshow(img_new_2_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=917x625>
# <PIL.Image.Image image mode=L size=917x625>

# %%
def calculate_lbp(img, x, y):
    center = img[x][y]
    values = []
    for i in range(-1, 2):
        for j in range(-1, 2):
            if i == 0 and j == 0:
                continue
            values.append(1 if img[x + i][y + j] >= center else 0)
    val = 0
    for i in range(len(values)):
      val+=values[i]*2**i

    return val


def apply_lbp(img):
    height, width = img.shape
    lbp_img = np.zeros((height, width), dtype=np.uint8)
    for i in range(1, height - 1):
        for j in range(1, width - 1):
            lbp_img[i, j] = calculate_lbp(img, i, j)
    return lbp_img

# %%
lbp_image_1 = apply_lbp(img_new_gray)
lbp_image_2 = apply_lbp(img_new_2_gray)
cv2_imshow(lbp_image_1)
cv2_imshow(lbp_image_2)
# Out:
# <PIL.Image.Image image mode=L size=895x607>
# <PIL.Image.Image image mode=L size=917x625>
